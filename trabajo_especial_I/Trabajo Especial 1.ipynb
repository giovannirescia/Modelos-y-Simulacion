# %%
import simulation as sim1
import simulation2 as sim2
import simulation3 as sim3
reload(sim3)
l1 = []
l2 = []
l3 = []
for i in range(10000):
    l1.append(sim1.esperanza(10))
    l2.append(sim2.esperanza(10))
    l3.append(sim3.esperanza(10))

# %%
axis([0, 8, 0, 1])
grid(True)
title('Esperanza de un lavadero')
xlabel('Esperanza de vida')
ylabel('Frecuencia observada')
text(3.5, 0.8, '$\sigma=1.7$')
hist(l1,100,normed=1 ,facecolor='g',alpha=0.44)
hist(l2,100,normed=1 ,facecolor='b',alpha=0.44)
hist(l3,100,normed=1 ,facecolor='r',alpha=0.44)
# Out:
# (array([ 0.0012684 ,  0.00634202,  0.00507361,  0.00634202,  0.01141563,
#         0.01775764,  0.02029445,  0.03171008,  0.05961495,  0.07229898,
#         0.09259343,  0.11288788,  0.14206116,  0.15220838,  0.15093998,
#         0.19279729,  0.19533409,  0.22450737,  0.25621745,  0.32978483,
#         0.31963761,  0.33993206,  0.34373727,  0.35388449,  0.37291054,
#         0.36530012,  0.37671575,  0.3944734 ,  0.37925256,  0.41730465,
#         0.40969423,  0.39954701,  0.40715743,  0.34627407,  0.36910533,
#         0.34246886,  0.30441677,  0.31202719,  0.29300114,  0.29680635,
#         0.26763308,  0.24480182,  0.26002266,  0.23338619,  0.25748585,
#         0.19026048,  0.19152888,  0.14840317,  0.16235561,  0.13571914,
#         0.1204983 ,  0.12937713,  0.1192299 ,  0.11669309,  0.09005663,
#         0.0811778 ,  0.06849377,  0.08244621,  0.05834655,  0.05200453,
#         0.05073613,  0.04566252,  0.03044168,  0.03424689,  0.04185731,
# ...
